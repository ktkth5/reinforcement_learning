# %%
import torch

# %%
l_q = torch.randn(2,12,2)
_, index = l_q.max(2)

# %%
index
# Out:
#     0     0     0     1     0     1     0     0     0     1     1     1
# [torch.LongTensor of size 1x12]

# %%
a_q = torch.arange(48).view(2,12,2)

# %%
torch.gather(l_q, 2, index.unsqueeze(2)).shape
# Out:
# torch.Size([2, 12, 1])

# %%
test = []
pri = 1
for i in range(10):
    test.append({"p":torch.FloatTensor([pri]), "e":pri*0.1})
    pri += 1

# %%
for i,data in enumerate(test):
    # print(data)
    if i == 0:
        # print(data["p"])
        x = data["p"]
    else:
        # print(data["p"])
        x = torch.cat((x, data["p"]),0)

# %%
indexes = torch.multinomial(x, 4)
indexes
# Out:
#  3
#  9
#  5
#  6
# [torch.LongTensor of size 4]

# %%
for i, index in enumerate(indexes):
    if i==0:
        ans = torch.Tensor([test[index]["e"]])
    else:
        ans = torch.cat((ans, torch.Tensor([test[index]["e"]])), 0)

# %%
ans
# Out:
#  0.4000
#  1.0000
#  0.6000
#  0.7000
# [torch.FloatTensor of size 4]

# %%
weights = torch.Tensor([0, 10, 3,1])

# %%
torch.multinomial(weights, 4,)
# Out:
#  1
#  2
#  3
#  0
# [torch.LongTensor of size 4]

# %%
list(map(int, ans))
# Out:
# [0, 1, 0, 0]

# %%
import numpy as np
import numpy.random as random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sigma = np.array([[2,1],[1,4]])
w, v = np.linalg.eig(sigma)

# %%
e = v * w

# %%
plt.plot([-1*e[0][0],e[0][0]], [-1*e[1][0],e[1][0]],"r")
plt.plot([-1*e[0][1],e[0][1]], [-1*e[1][1],e[1][1]],"b")

# %%
plt.plot([-2,2],[-1,1],"r")
plt.plot([-1,1],[-4,4],"b")

# %%
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D
m = 2
mean = np.zeros(m)
sigma = np.array([[2,1],[1,4]])
N = 1000
x1 = np.linspace(-5, 5, N)
x2 = np.linspace(-5, 5, N)
X1, X2 = np.meshgrid(x1, x2)
X = np.c_[np.ravel(X1), np.ravel(X2)]
Y_plot = multivariate_normal.pdf(x=X, mean=mean, cov=sigma)
Y_plot = Y_plot.reshape(X1.shape)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X1, X2, Y_plot, cmap='bwr', linewidth=0)
fig.colorbar(surf)
ax.set_title("Surface Plot")
fig.show()
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D
m = 2 #dimension
mean = np.zeros(m)
sigma = np.array([[-1.46507563, -1.6892464 ],
                   [ 0.6068542 , -4.07820156]])

N = 1000
x1 = np.linspace(-5, 5, N)
x2 = np.linspace(-5, 5, N)

X1, X2 = np.meshgrid(x1, x2)
X = np.c_[np.ravel(X1), np.ravel(X2)]

Y_plot = multivariate_normal.pdf(x=X, mean=mean, cov=sigma)
Y_plot = Y_plot.reshape(X1.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X1, X2, Y_plot, cmap='bwr', linewidth=0)
fig.colorbar(surf)
ax.set_title("Surface Plot")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-248-74451ca7659f> in <module>()
#      13 X = np.c_[np.ravel(X1), np.ravel(X2)]
#      14
# ---> 15 Y_plot = multivariate_normal.pdf(x=X, mean=mean, cov=sigma)
#      16 Y_plot = Y_plot.reshape(X1.shape)
#      17
#
# /usr/local/lib/python3.6/site-packages/scipy/stats/_multivariate.py in pdf(self, x, mean, cov, allow_singular)
#     510         dim, mean, cov = self._process_parameters(None, mean, cov)
#     511         x = self._process_quantiles(x, dim)
# --> 512         psd = _PSD(cov, allow_singular=allow_singular)
#     513         out = np.exp(self._logpdf(x, mean, psd.U, psd.log_pdet, psd.rank))
#     514         return _squeeze_output(out)
#
# /usr/local/lib/python3.6/site-packages/scipy/stats/_multivariate.py in __init__(self, M, cond, rcond, lower, check_finite, allow_singular)
# ...
